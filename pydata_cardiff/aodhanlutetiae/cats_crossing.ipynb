# %% [raw]
# ---
# title: "UK cats crossing in 2017 in Cornwall"
# date: "April 6, 2023"
#
# toc: true
# number-sections: true
# highlight-style: pygments
#
# format:
#   html:
#     code-fold: true
#     code-tools: true
#
# jupyter: python3
# ---

# %% [markdown]
# ## Background

# %% [markdown]
# > A main dataset records about 18,000 cat 'events' via sensors attached to 101 cats in Cornwall, UK during the second half of 2017. A second dataset gives details on each of the cats. One possible question is: did any of the cats meet during this period? An answer: Two cats came within 12m of each other late one night in mid-July.

# %% [raw]
# ::: {.column-margin}
#
# > [https://www.meetup.com/pydata-cardiff-meetup/events/292238149/](https://www.meetup.com/pydata-cardiff-meetup/events/292238149/)
#
# > [https://github.com/pydatacardiff/snake-cat-hack](https://github.com/pydatacardiff/snake-cat-hack)
#
# > [https://www.datarepository.movebank.org/handle/10255/move.882](https://www.datarepository.movebank.org/handle/10255/move.882)
#
# > [https://gis.stackexchange.com/questions/157005/meaning-of-elevation-above-surface-of-ellipsoid](https://gis.stackexchange.com/questions/157005/meaning-of-elevation-above-surface-of-ellipsoid)
#
# :::

# %% [markdown]
# ## Imports & cleaning

# %%
import pandas as pd
pd.set_option('display.max_columns', 200)

import folium

from pyproj import Geod
wgs84_geod = Geod(ellps='WGS84')

import warnings
warnings.simplefilter(action = 'ignore', category = Warning)

# %%
# import reference file

path = '/Users/compj/Documents/DATA/ALL_DATASETS/cats/'
file = 'cats_uk_ref.csv'

dfr = pd.read_csv(path+file)
print(dfr.shape)

dfr[:2]
# Out:
# (101, 21)
#       tag-id animal-id animal-taxon           deploy-on-date  \
# 0  Tommy-Tag     Tommy  Felis catus  2017-06-03 01:02:09.000
# 1     Athena    Athena  Felis catus  2017-06-24 01:02:13.000
#
#            deploy-off-date                animal-comments animal-life-stage  \
# 0  2017-06-10 02:10:52.000  Hunt: Yes; prey_p_month: 12.5          11 years
# 1  2017-06-30 23:59:32.000     Hunt: Yes; prey_p_month: 3           3 years
#
#   animal-reproductive-condition animal-sex attachment-type  ...  \
# 0                      Neutered          m          collar  ...
# 1                        Spayed          f          collar  ...
#
#   deployment-end-type deployment-id   duty-cycle  \
# 0             removal         Tommy  3-min fixes
# 1             removal        Athena  3-min fixes
#
#                                manipulation-comments  manipulation-type  \
# 0  hrs_indoors: 12.5; n_cats: 2; Food: Dry- Yes, ...  manipulated other
# 1  hrs_indoors: 7.5; n_cats: 2; Food: Dry- Yes, W...  manipulated other
#
#   study-site           tag-manufacturer-name tag-mass  tag-model  \
# 0         UK  Mobile Action Technology, Inc.    119.0     i-GotU
# 1         UK  Mobile Action Technology, Inc.    119.0     i-GotU
#
#   tag-readout-method
# 0      tag retreival
# 1      tag retreival
#
# [2 rows x 21 columns]

# %%
# variables for each cat

dfr.columns
# Out:
# Index(['tag-id', 'animal-id', 'animal-taxon', 'deploy-on-date',
#        'deploy-off-date', 'animal-comments', 'animal-life-stage',
#        'animal-reproductive-condition', 'animal-sex', 'attachment-type',
#        'data-processing-software', 'deployment-end-type', 'deployment-id',
#        'duty-cycle', 'manipulation-comments', 'manipulation-type',
#        'study-site', 'tag-manufacturer-name', 'tag-mass', 'tag-model',
#        'tag-readout-method'],
#       dtype='object')

# %%
# import events file

path = '/Users/compj/Documents/DATA/ALL_DATASETS/cats/'
file = 'cats_uk.csv'

df = pd.read_csv(path+file)
print(df.shape)
df[:3]
# Out:
# (18215, 14)
#      event-id  visible                timestamp  location-long  location-lat  \
# 0  3395610551     True  2017-06-24 01:03:57.000      -5.113851     50.170315
# 1  3395610552     True  2017-06-24 01:11:20.000      -5.113851     50.170315
# 2  3395610553     True  2017-06-24 02:58:16.000      -5.113730     50.169876
#
#   algorithm-marked-outlier  ground-speed  height-above-ellipsoid  \
# 0                      NaN         684.0                  154.67
# 1                      NaN         936.0                  154.67
# 2                      NaN        2340.0                   81.35
#
#   manually-marked-outlier sensor-type individual-taxon-canonical-name  \
# 0                     NaN         gps                     Felis catus
# 1                     NaN         gps                     Felis catus
# 2                     NaN         gps                     Felis catus
#
#   tag-local-identifier individual-local-identifier               study-name
# 0                 Ares                        Ares  Pet Cats United Kingdom
# 1                 Ares                        Ares  Pet Cats United Kingdom
# 2                 Ares                        Ares  Pet Cats United Kingdom

# %%
# print columns for renaming

df.columns
# Out:
# Index(['event-id', 'visible', 'timestamp', 'location-long', 'location-lat',
#        'algorithm-marked-outlier', 'ground-speed', 'height-above-ellipsoid',
#        'manually-marked-outlier', 'sensor-type',
#        'individual-taxon-canonical-name', 'tag-local-identifier',
#        'individual-local-identifier', 'study-name'],
#       dtype='object')

# %%
# rename cols

df.columns = ['event_id', 'visible', 'time', 'long', 'lat',
       'algo_outlier', 'speed_ms', 'height_m',
       'manual_outlier', 'sensor', 'individual_taxon_canonical_name',
       'tag_name', 'name', 'study']

# %%
# single observation in variables: sensor, individual-taxon-canonical-name, study. All occur 18215 times, so DROPPED
# drop 'ground speed' column as data too suspect

df = df[['event_id', 'visible', 'time', 'lat', 'long', 'height_m',
         'tag_name', 'name', 'algo_outlier', 'manual_outlier']]

# %%
# cast time to datetime (from string)

df['time'] = df['time'].astype('datetime64[ns]')

# %%
# add epoch col

df['epoch'] = df.time.apply(lambda x: x.timestamp())

# %%
# build dict to match each of the 101 animals with sex (from reference dataframe)

dd = dfr[['animal-id', 'animal-sex']]
this_dict = dict(zip(dd['animal-id'], dd['animal-sex']))

# map sex onto event dataset
df['sex'] = df.name.map(this_dict)

# %%
# remove outliers

df = df[df.algo_outlier != True]
df = df[df.manual_outlier != True]

# %%
# a clean, reduced, df

print(df.shape)
df[:3]
# Out:
# (17866, 12)
#      event_id  visible                time        lat      long  height_m  \
# 0  3395610551     True 2017-06-24 01:03:57  50.170315 -5.113851    154.67
# 1  3395610552     True 2017-06-24 01:11:20  50.170315 -5.113851    154.67
# 2  3395610553     True 2017-06-24 02:58:16  50.169876 -5.113730     81.35
#
#   tag_name  name algo_outlier manual_outlier         epoch sex
# 0     Ares  Ares          NaN            NaN  1.498266e+09   m
# 1     Ares  Ares          NaN            NaN  1.498267e+09   m
# 2     Ares  Ares          NaN            NaN  1.498273e+09   m

# %% [markdown]
# ## Did two cats meet at any point?

# %%
# what time stamps occur more than once?

df.time.value_counts()
# Out:
# 2017-07-22 23:10:14    2
# 2017-07-15 00:07:00    2
# 2017-07-21 00:02:18    2
# 2017-07-29 09:58:57    2
# 2017-07-24 00:07:10    2
#                       ..
# 2017-07-20 14:24:20    1
# 2017-07-20 15:11:12    1
# 2017-07-20 22:43:38    1
# 2017-07-20 22:46:57    1
# 2017-11-27 00:09:29    1
# Name: time, Length: 17817, dtype: int64

# %%
# collect list of the 49 timestamps that occur twice

times_list = list(df.time.value_counts().iloc[0:49].index)

# %%
# look at a matching pair

df[df.time == times_list[4]]
# Out:
#         event_id  visible                time        lat      long  height_m  \
# 5605  3459579723     True 2017-07-24 00:07:10  50.438293 -4.609500    149.23
# 6239  3466874756     True 2017-07-24 00:07:10  50.149246 -5.077589     61.92
#
#          tag_name     name algo_outlier manual_outlier         epoch sex
# 5605      Tom-Tag      Tom          NaN            NaN  1.500855e+09   f
# 6239  Bumbles-Tag  Bumbles          NaN            NaN  1.500855e+09   f

# %%
# build df containing only timestamps that occur twice

pairs = pd.DataFrame(df[df.time.isin(times_list) == True])

# %%
# define df as ordered by matched pairs

pairs = pairs.sort_values('time')

# %%
pairs.head(6)
# Out:
#         event_id  visible                time        lat      long  height_m  \
# 84    3395610635     True 2017-06-30 07:52:42  50.170071 -5.114016     79.82
# 416   3395925965     True 2017-06-30 07:52:42  50.146648 -5.073758     28.05
# 1176  3403154374     True 2017-07-02 00:02:02  50.152744 -5.076456     56.04
# 1773  3407154381     True 2017-07-02 00:02:02  50.158855 -5.086765    147.56
# 2007  3407233488     True 2017-07-09 23:33:51  50.155525 -5.080747     62.33
# 3569  3434335229     True 2017-07-09 23:33:51  50.406281 -4.232153     35.63
#
#           tag_name      name algo_outlier manual_outlier         epoch sex
# 84            Ares      Ares          NaN            NaN  1.498809e+09   m
# 416           Lola      Lola          NaN            NaN  1.498809e+09   f
# 1176          Coco      Coco          NaN            NaN  1.498954e+09   f
# 1773    Nettle-Tag    Nettle          NaN            NaN  1.498954e+09   f
# 2007  Carbonel-Tag  Carbonel          NaN            NaN  1.499643e+09   m
# 3569    Fonzie-Tag    Fonzie          NaN            NaN  1.499643e+09   m

# %%
# build a list of pairs of event_ids: rows 1&2, 3&4 etc

idlist = []
a = 0
b = 1

for x in range(48):
    
    id1 = pairs.event_id.iloc[a]
    id2 = pairs.event_id.iloc[b]
    pair = [id1, id2]
    idlist.append(pair)
    
    a = a+2
    b = b+2

# %%
# which gives, for example...

idlist[7]
# Out:
# [3424068549, 3434650508]

# %%
# Function to get distance between pairs of lat-lon points in meters

def Distance(id1, id2, pairs):
    az12,az21,dist = wgs84_geod.inv(pairs[pairs.event_id == id1].long,
                                  pairs[pairs.event_id == id1].lat,
                                  pairs[pairs.event_id == id2].long,
                                  pairs[pairs.event_id == id2].lat)
    return dist[0]

# %%
Distance(3669580557, 3669580563, pairs)
# Out:
# 8.098774495702012

# %%
# return distance between each pair of two points that share a timestamp: assemble results into a list of lists

dist_list = []

for x in idlist:
    event1 = x[0]
    found_distance = Distance(x[0], x[1], df)
    entry_list = []
    entry_list.extend((found_distance, x))
    dist_list.append(entry_list)

# %%
# sort the list by smallest distance
dist_list.sort(key = lambda x:x[0])

# show the first ten shortest
dist_list[:10]
# Out:
# [[12.093935837150926, [3424068550, 3411705019]],
#  [24.73185196794881, [3669580557, 3669564051]],
#  [27.990842098322485, [3669580563, 3669564064]],
#  [49.77572199512557, [3459579605, 3459516210]],
#  [82.73165352109858, [3669558771, 3669563963]],
#  [148.99185925349062, [3507105157, 3507104834]],
#  [187.8196191221107, [3544856075, 3544857618]],
#  [220.4351567214042, [3466879300, 3467011822]],
#  [487.6847762295395, [3459516358, 3459579774]],
#  [1002.3981294601922, [3403154374, 3407154381]]]

# %%
# 1st and 2nd instance in the 12m pair

pairs[(pairs.event_id == 3424068550) | (pairs.event_id == 3411705019)]
# Out:
#         event_id  visible                time        lat      long  height_m  \
# 3179  3424068550     True 2017-07-16 00:18:00  50.147152 -5.062538     53.66
# 2677  3411705019     True 2017-07-16 00:18:00  50.147228 -5.062417     30.21
#
#        tag_name   name algo_outlier manual_outlier         epoch sex
# 3179  Rusty-Tag  Rusty          NaN            NaN  1.500164e+09   m
# 2677  Indie-Tag  Indie          NaN            NaN  1.500164e+09   m

# %%
# Who are these two cats? See reference dataset

dfr[(dfr['animal-id'] == 'Rusty') | (dfr['animal-id'] == 'Indie')]
# Out:
#        tag-id animal-id animal-taxon           deploy-on-date  \
# 17  Indie-Tag     Indie  Felis catus  2017-07-09 01:03:00.000
# 19  Rusty-Tag     Rusty  Felis catus  2017-07-09 02:19:00.000
#
#             deploy-off-date               animal-comments animal-life-stage  \
# 17  2017-07-16 09:33:00.000  Hunt: Yes; prey_p_month: 0.5           3 years
# 19  2017-07-16 00:34:00.000    Hunt: Yes; prey_p_month: 3           4 years
#
#    animal-reproductive-condition animal-sex attachment-type  \
# 17                      Neutered          m          collar
# 19                      Neutered          m          collar
#
#    data-processing-software deployment-end-type deployment-id   duty-cycle  \
# 17                 @Trip PC             removal         Indie  3-min fixes
# 19                 @Trip PC             removal         Rusty  3-min fixes
#
#                                 manipulation-comments  manipulation-type  \
# 17  hrs_indoors: 17.5; n_cats: 2; Food: Dry- Yes, ...  manipulated other
# 19  hrs_indoors: 17.5; n_cats: 1; Food: Dry- Yes, ...  manipulated other
#
#    study-site           tag-manufacturer-name  tag-mass tag-model  \
# 17         UK  Mobile Action Technology, Inc.     119.0    i-GotU
# 19         UK  Mobile Action Technology, Inc.     119.0    i-GotU
#
#    tag-readout-method
# 17      tag retreival
# 19      tag retreival

# %%
# filter a df for each of the 2 cats
rusty = df[df.name == 'Rusty']
indie = df[df.name == 'Indie']

# filter each of the cat datasets down to 2 days since they cross overnight July 15-16
rusty_2d = rusty[(rusty['time'].dt.strftime('%Y-%m-%d') == '2017-07-15') | (rusty['time'].dt.strftime('%Y-%m-%d') == '2017-07-16')]
indie_2d = indie[(indie['time'].dt.strftime('%Y-%m-%d') == '2017-07-15') | (indie['time'].dt.strftime('%Y-%m-%d') == '2017-07-16')]

# extract rusty lat, longs to a list
list_rusty_locs = list(zip(rusty_2d.lat, rusty_2d.long))

# extract indie lat, longs to a list
list_indie_locs = list(zip(indie_2d.lat, indie_2d.long))

# %% [markdown]
# ## Rusty & Indie, 18 mins past midnight on July 16, 2017
#
# > Map shows all points recorded for Rusty (red) and Indie (green) on July 15th and 16th, 2017. The larger points show where each was situated at 00:18 on July 16

# %%
# create folium map base
mapit = folium.Map(location=[50.147228, -5.062417], zoom_start=18)

# choose tiles from Carto db
folium.TileLayer('cartodbpositron').add_to(mapit)

# plot all rusty locations for those 2 days on low opacity
for coord in list_rusty_locs:
    folium.CircleMarker(location=[coord[0],coord[1]], 
                        color='red', 
                        opacity = 0.2,
                        fill_opacity = 0.2,
                        fill_color = 'red',
                        radius=2).add_to(mapit)
    
# plot all indie locations for those 2 days on low opacity
for coord in list_indie_locs:
    folium.CircleMarker(location=[coord[0],coord[1]], 
                        color='green', 
                        opacity = 0.2,
                        fill_opacity = 0.2,
                        fill_color = 'green',
                        radius=2).add_to(mapit)
    
# rusty crossing point on full opacity
folium.CircleMarker(location=[50.147152, -5.062538], 
                    color='red', 
                    opacity = 1.0,
                    fill_opacity = 1.0,
                    fill_color = 'red',
                    radius=4).add_to(mapit)

# indie crossing point on full opacity
folium.CircleMarker(location=[50.147228, -5.062417], 
                    color='green', 
                    opacity = 1.0,
                    fill_opacity = 1.0,
                    fill_color = 'green',
                    radius=4).add_to(mapit)

mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b74792f034d20be975b74b01ad9775e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b74792f034d20be975b74b01ad9775e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b74792f034d20be975b74b01ad9775e = L.map(
#                 &quot;map_9b74792f034d20be975b74b01ad9775e&quot;,
#                 {
#                     center: [50.147228, -5.062417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9b46968d3e247581fcf8e2b4958c5bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9b74792f034d20be975b74b01ad9775e);
#
#
#             var tile_layer_34f282791734e1d5d544b9263abef8a5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9b74792f034d20be975b74b01ad9775e);
#
#
#             var circle_marker_8872f59f0ee54baefee615d89d0f66b8 = L.circleMarker(
#                 [50.147125, -5.062063],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9b74792f034d20be975b74b01ad9775e);
#
#
#             var circle_marker_0496d9dde338b1bf75a562cbdb820c8f = L.circleMarker(
#                 [50.147125, -5.062063],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9b74792f034d20be975b74b01ad9775e);
#
#
#             var circle_marker_6ce7ddcc7780304334b2ba9cabe5cc1b = L.circleMarker(
#                 [50.147179, -5.062533],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9b74792f034d20be975b74b01ad9775e);
#
#
#             var circle_marker_8da29bde6be33bda8937f439b3c65429 = L.circleMarker(
#                 [50.147266, -5.062506],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9b74792f034d20be975b74b01ad9775e);
#
#
#             var circle_marker_72e67af4d0230dd5b08634ab0d17b69e = L.circleMarker(
#                 [50.14695, -5.062383],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9b74792f034d20be975b74b01ad9775e);
#
#
#             var circle_marker_5bc59688fac
